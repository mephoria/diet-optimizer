# %%
import requests

# %%
r = requests.post('https://api.pcexpress.ca/pcx-bff/api/v2/listingPage/28194')

# %%
r.text
# Out:
# '\n                {"error":"invalid_client","error_description":"The client credentials provided were invalid, the request is unauthorized."}\n            '
